# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer 
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
df = pd.read_csv('./data/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1            80                 0
# 1  ...                         4            80                 1
# 2  ...                         2            80                 0
# 3  ...                         3            80                 0
# 4  ...                         4            80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
df["Over18"].value_counts()
# Out:
# Y    1470
# Name: Over18, dtype: int64

# %%
df.drop(['OverTime','Over18','EmployeeCount', 'EmployeeNumber', 'StandardHours'], axis="columns", inplace=True)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0  Female  ...                  3                         1                 0
# 1    Male  ...                  4                         4                 1
# 2    Male  ...                  3                         2                 0
# 3  Female  ...                  3                         3                 0
# 4    Male  ...                  3                         4                 1
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                 8                      0               1               6
# 1                10                      3               3              10
# 2                 7                      3               3               0
# 3                 8                      3               3               8
# 4                 6                      3               3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
# [5 rows x 30 columns]

# %%
X = df.drop("Attrition",axis=1)
y= df["Attrition"]

# %%
X
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      41      Travel_Rarely       1102                   Sales
# 1      49  Travel_Frequently        279  Research & Development
# 2      37      Travel_Rarely       1373  Research & Development
# 3      33  Travel_Frequently       1392  Research & Development
# 4      27      Travel_Rarely        591  Research & Development
# ...   ...                ...        ...                     ...
# 1465   36  Travel_Frequently        884  Research & Development
# 1466   39      Travel_Rarely        613  Research & Development
# 1467   27      Travel_Rarely        155  Research & Development
# 1468   49  Travel_Frequently       1023                   Sales
# 1469   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                    1          2  Life Sciences                        2
# 1                    8          1  Life Sciences                        3
# 2                    2          2          Other                        4
# 3                    3          4  Life Sciences                        4
# 4                    2          1        Medical                        1
# ...                ...        ...            ...                      ...
# 1465                23          2        Medical                        3
# 1466                 6          1        Medical                        4
# 1467                 4          3  Life Sciences                        2
# 1468                 2          3        Medical                        4
# 1469                 8          3        Medical                        2
#
#       Gender  HourlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# 0     Female          94  ...                  3                         1
# 1       Male          61  ...                  4                         4
# 2       Male          92  ...                  3                         2
# 3     Female          56  ...                  3                         3
# 4       Male          40  ...                  3                         4
# ...      ...         ...  ...                ...                       ...
# 1465    Male          41  ...                  3                         3
# 1466    Male          42  ...                  3                         1
# 1467    Male          87  ...                  4                         2
# 1468    Male          63  ...                  3                         4
# 1469    Male          82  ...                  3                         1
#
#      StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 0                   0                  8                     0
# 1                   1                 10                     3
# 2                   0                  7                     3
# 3                   0                  8                     3
# 4                   1                  6                     3
# ...               ...                ...                   ...
# 1465                1                 17                     3
# 1466                1                  9                     5
# 1467                1                  6                     0
# 1468                0                 17                     3
# 1469                0                  6                     3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                   1               6                   4
# 1                   3              10                   7
# 2                   3               0                   0
# 3                   3               8                   7
# 4                   3               2                   2
# ...               ...             ...                 ...
# 1465                3               5                   2
# 1466                3               7                   7
# 1467                3               6                   2
# 1468                2               9                   6
# 1469                4               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 0                           0                     5
# 1                           1                     7
# 2                           0                     0
# 3                           3                     0
# 4                           2                     2
# ...                       ...                   ...
# 1465                        0                     3
# 1466                        1                     7
# 1467                        0                     3
# 1468                        0                     8
# 1469                        1                     2
#
# [1470 rows x 29 columns]

# %%
y
# Out:
# 0       Yes
# 1        No
# 2       Yes
# 3        No
# 4        No
#        ...
# 1465     No
# 1466     No
# 1467     No
# 1468     No
# 1469     No
# Name: Attrition, Length: 1470, dtype: object

# %%
X.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
X.shape
# Out:
# (1470, 29)

# %%
X.select_dtypes(include="O")
# Out:
#          BusinessTravel              Department EducationField  Gender  \
# 0         Travel_Rarely                   Sales  Life Sciences  Female
# 1     Travel_Frequently  Research & Development  Life Sciences    Male
# 2         Travel_Rarely  Research & Development          Other    Male
# 3     Travel_Frequently  Research & Development  Life Sciences  Female
# 4         Travel_Rarely  Research & Development        Medical    Male
# ...                 ...                     ...            ...     ...
# 1465  Travel_Frequently  Research & Development        Medical    Male
# 1466      Travel_Rarely  Research & Development        Medical    Male
# 1467      Travel_Rarely  Research & Development  Life Sciences    Male
# 1468  Travel_Frequently                   Sales        Medical    Male
# 1469      Travel_Rarely  Research & Development        Medical    Male
#
#                         JobRole MaritalStatus
# 0               Sales Executive        Single
# 1            Research Scientist       Married
# 2         Laboratory Technician        Single
# 3            Research Scientist       Married
# 4         Laboratory Technician       Married
# ...                         ...           ...
# 1465      Laboratory Technician       Married
# 1466  Healthcare Representative       Married
# 1467     Manufacturing Director       Married
# 1468            Sales Executive       Married
# 1469      Laboratory Technician       Married
#
# [1470 rows x 6 columns]

# %%
X.select_dtypes(include="O").columns
# Out:
# Index(['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole',
#        'MaritalStatus'],
#       dtype='object')

# %%
categorical_features = list(X.select_dtypes(include="O").columns)
categorical_features
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus']

# %%
X.select_dtypes(include="number")
# Out:
#       Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0      41       1102                 1          2                        2
# 1      49        279                 8          1                        3
# 2      37       1373                 2          2                        4
# 3      33       1392                 3          4                        4
# 4      27        591                 2          1                        1
# ...   ...        ...               ...        ...                      ...
# 1465   36        884                23          2                        3
# 1466   39        613                 6          1                        4
# 1467   27        155                 4          3                        2
# 1468   49       1023                 2          3                        4
# 1469   34        628                 8          3                        2
#
#       HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  \
# 0             94               3         2                4           5993
# 1             61               2         2                2           5130
# 2             92               2         1                3           2090
# 3             56               3         1                3           2909
# 4             40               3         1                2           3468
# ...          ...             ...       ...              ...            ...
# 1465          41               4         2                4           2571
# 1466          42               2         3                1           9991
# 1467          87               4         2                2           6142
# 1468          63               2         2                2           5390
# 1469          82               4         2                3           4404
#
#       ...  PerformanceRating  RelationshipSatisfaction  StockOptionLevel  \
# 0     ...                  3                         1                 0
# 1     ...                  4                         4                 1
# 2     ...                  3                         2                 0
# 3     ...                  3                         3                 0
# 4     ...                  3                         4                 1
# ...   ...                ...                       ...               ...
# 1465  ...                  3                         3                 1
# 1466  ...                  3                         1                 1
# 1467  ...                  4                         2                 1
# 1468  ...                  3                         4                 0
# 1469  ...                  3                         1                 0
#
#       TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                     8                      0                1
# 1                    10                      3                3
# 2                     7                      3                3
# 3                     8                      3                3
# 4                     6                      3                3
# ...                 ...                    ...              ...
# 1465                 17                      3                3
# 1466                  9                      5                3
# 1467                  6                      0                3
# 1468                 17                      3                2
# 1469                  6                      3                4
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 0                  6                   4                        0
# 1                 10                   7                        1
# 2                  0                   0                        0
# 3                  8                   7                        3
# 4                  2                   2                        2
# ...              ...                 ...                      ...
# 1465               5                   2                        0
# 1466               7                   7                        1
# 1467               6                   2                        0
# 1468               9                   6                        0
# 1469               4                   3                        1
#
#       YearsWithCurrManager
# 0                        5
# 1                        7
# 2                        0
# 3                        0
# 4                        2
# ...                    ...
# 1465                     3
# 1466                     7
# 1467                     3
# 1468                     8
# 1469                     2
#
# [1470 rows x 23 columns]

# %%
X.select_dtypes(include="number").columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
numerical_features = list(X.select_dtypes(include="number").columns)
numerical_features
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
train_data, test_data, train_y, test_y = train_test_split(X, y,
                                                   random_state = 42, test_size = 0.30,
                                                   stratify = y)

# %%
X.shape
# Out:
# (1470, 29)

# %%
y.shape
# Out:
# (1470,)

# %%
train_data.shape
# Out:
# (1029, 29)

# %%
test_data.shape
# Out:
# (441, 29)

# %%
train_y.shape
# Out:
# (1029,)

# %%
test_y.shape
# Out:
# (441,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.30,
                                                    random_state=42,
                                                    stratify=y)

# %%
X_train.head()
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 853    19      Travel_Rarely        645  Research & Development
# 435    33      Travel_Rarely       1277  Research & Development
# 587    52      Travel_Rarely       1325  Research & Development
# 1170   27  Travel_Frequently        591  Research & Development
# 159    34  Travel_Frequently        303                   Sales
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 853                  9          2  Life Sciences                        3
# 435                 15          1        Medical                        2
# 587                 11          4  Life Sciences                        4
# 1170                 2          3        Medical                        4
# 159                  2          4      Marketing                        3
#
#       Gender  HourlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# 853     Male          54  ...                  4                         3
# 435     Male          56  ...                  3                         4
# 587   Female          82  ...                  4                         2
# 1170    Male          87  ...                  3                         3
# 159   Female          75  ...                  3                         4
#
#      StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 853                 0                  1                     4
# 435                 0                 15                     2
# 587                 1                  9                     3
# 1170                0                  6                     0
# 159                 1                  6                     3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 853                 3               1                   1
# 435                 4               7                   6
# 587                 3               5                   2
# 1170                2               4                   2
# 159                 3               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 853                         0                     0
# 435                         7                     7
# 587                         1                     4
# 1170                        1                     2
# 159                         1                     2
#
# [5 rows x 29 columns]

# %%
ohe_encoder = OneHotEncoder()
ord_encoder = OrdinalEncoder()

# %%
ct = make_column_transformer( 
            (ord_encoder,["BusinessTravel"]),
            (ohe_encoder, ["Department","EducationField", "Gender","JobRole", "MaritalStatus"]),
            remainder = 'passthrough')

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

pipe = Pipeline([
    ('Column_Transformations', ct),
    ('Logistic Regression', LogisticRegression()),
])

# %%
X_train.head()
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 853    19      Travel_Rarely        645  Research & Development
# 435    33      Travel_Rarely       1277  Research & Development
# 587    52      Travel_Rarely       1325  Research & Development
# 1170   27  Travel_Frequently        591  Research & Development
# 159    34  Travel_Frequently        303                   Sales
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 853                  9          2  Life Sciences                        3
# 435                 15          1        Medical                        2
# 587                 11          4  Life Sciences                        4
# 1170                 2          3        Medical                        4
# 159                  2          4      Marketing                        3
#
#       Gender  HourlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# 853     Male          54  ...                  4                         3
# 435     Male          56  ...                  3                         4
# 587   Female          82  ...                  4                         2
# 1170    Male          87  ...                  3                         3
# 159   Female          75  ...                  3                         4
#
#      StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 853                 0                  1                     4
# 435                 0                 15                     2
# 587                 1                  9                     3
# 1170                0                  6                     0
# 159                 1                  6                     3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 853                 3               1                   1
# 435                 4               7                   6
# 587                 3               5                   2
# 1170                2               4                   2
# 159                 3               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 853                         0                     0
# 435                         7                     7
# 587                         1                     4
# 1170                        1                     2
# 159                         1                     2
#
# [5 rows x 29 columns]

# %%
y.head()
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3     No
# 4     No
# Name: Attrition, dtype: object

# %%
pipe.fit(X_train, y_train)
# Out:
# /Users/DEEPANSHU/Folder001/Git_Projects/MLOps/IBM_Employee_Attrition_Prediciton/venv/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('Column_Transformations',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinalencoder',
#                                                   OrdinalEncoder(),
#                                                   ['BusinessTravel']),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(),
#                                                   ['Department',
#                                                    'EducationField', 'Gender',
#                                                    'JobRole',
#                                                    'MaritalStatus'])])),
#                 ('Logistic Regression', LogisticRegression())])

# %%
y_pred = pipe.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.8412698412698413

# %%
y_pred = pipe.predict_proba(X_test)[:,1]
roc_auc_score(y_test, y_pred)
# Out:
# 0.6650171298058623

# %%
X_train.head()
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 853    19      Travel_Rarely        645  Research & Development
# 435    33      Travel_Rarely       1277  Research & Development
# 587    52      Travel_Rarely       1325  Research & Development
# 1170   27  Travel_Frequently        591  Research & Development
# 159    34  Travel_Frequently        303                   Sales
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 853                  9          2  Life Sciences                        3
# 435                 15          1        Medical                        2
# 587                 11          4  Life Sciences                        4
# 1170                 2          3        Medical                        4
# 159                  2          4      Marketing                        3
#
#       Gender  HourlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# 853     Male          54  ...                  4                         3
# 435     Male          56  ...                  3                         4
# 587   Female          82  ...                  4                         2
# 1170    Male          87  ...                  3                         3
# 159   Female          75  ...                  3                         4
#
#      StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 853                 0                  1                     4
# 435                 0                 15                     2
# 587                 1                  9                     3
# 1170                0                  6                     0
# 159                 1                  6                     3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 853                 3               1                   1
# 435                 4               7                   6
# 587                 3               5                   2
# 1170                2               4                   2
# 159                 3               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 853                         0                     0
# 435                         7                     7
# 587                         1                     4
# 1170                        1                     2
# 159                         1                     2
#
# [5 rows x 29 columns]

# %%
train_probas = pd.DataFrame(pipe.predict_proba(X_train))
train_probas
# Out:
#              0         1
# 0     0.657474  0.342526
# 1     0.868217  0.131783
# 2     0.859321  0.140679
# 3     0.834872  0.165128
# 4     0.812314  0.187686
# ...        ...       ...
# 1024  0.831317  0.168683
# 1025  0.911079  0.088921
# 1026  0.739918  0.260082
# 1027  0.840986  0.159014
# 1028  0.721713  0.278287
#
# [1029 rows x 2 columns]

# %%
train_probas.columns = ['no', 'yes']

# %%
train_probas
# Out:
#             no       yes
# 0     0.657474  0.342526
# 1     0.868217  0.131783
# 2     0.859321  0.140679
# 3     0.834872  0.165128
# 4     0.812314  0.187686
# ...        ...       ...
# 1024  0.831317  0.168683
# 1025  0.911079  0.088921
# 1026  0.739918  0.260082
# 1027  0.840986  0.159014
# 1028  0.721713  0.278287
#
# [1029 rows x 2 columns]

# %%
test_probas = pd.DataFrame(pipe.predict_proba(X_test))
test_probas.columns = ['no', 'yes']
test_probas
# Out:
#            no       yes
# 0    0.853423  0.146577
# 1    0.648445  0.351555
# 2    0.615813  0.384187
# 3    0.808127  0.191873
# 4    0.892689  0.107311
# ..        ...       ...
# 436  0.832132  0.167868
# 437  0.851662  0.148338
# 438  0.916526  0.083474
# 439  0.764707  0.235293
# 440  0.964593  0.035407
#
# [441 rows x 2 columns]

# %%
X_train
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 853    19      Travel_Rarely        645  Research & Development
# 435    33      Travel_Rarely       1277  Research & Development
# 587    52      Travel_Rarely       1325  Research & Development
# 1170   27  Travel_Frequently        591  Research & Development
# 159    34  Travel_Frequently        303                   Sales
# ...   ...                ...        ...                     ...
# 365    46         Non-Travel       1144  Research & Development
# 963    38      Travel_Rarely       1009                   Sales
# 734    22      Travel_Rarely        217  Research & Development
# 1315   36      Travel_Rarely        430  Research & Development
# 1292   39  Travel_Frequently        766                   Sales
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 853                  9          2  Life Sciences                        3
# 435                 15          1        Medical                        2
# 587                 11          4  Life Sciences                        4
# 1170                 2          3        Medical                        4
# 159                  2          4      Marketing                        3
# ...                ...        ...            ...                      ...
# 365                  7          4        Medical                        3
# 963                  2          2  Life Sciences                        2
# 734                  8          1  Life Sciences                        2
# 1315                 2          4          Other                        4
# 1292                20          3  Life Sciences                        3
#
#       Gender  HourlyRate  ...  PerformanceRating  RelationshipSatisfaction  \
# 853     Male          54  ...                  4                         3
# 435     Male          56  ...                  3                         4
# 587   Female          82  ...                  4                         2
# 1170    Male          87  ...                  3                         3
# 159   Female          75  ...                  3                         4
# ...      ...         ...  ...                ...                       ...
# 365   Female          30  ...                  3                         3
# 963   Female          31  ...                  3                         4
# 734     Male          94  ...                  3                         1
# 1315  Female          73  ...                  4                         4
# 1292    Male          83  ...                  3                         4
#
#      StockOptionLevel  TotalWorkingYears TrainingTimesLastYear  \
# 853                 0                  1                     4
# 435                 0                 15                     2
# 587                 1                  9                     3
# 1170                0                  6                     0
# 159                 1                  6                     3
# ...               ...                ...                   ...
# 365                 0                  7                     2
# 963                 1                 11                     3
# 734                 1                  4                     3
# 1315                1                 15                     2
# 1292                1                  7                     6
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 853                 3               1                   1
# 435                 4               7                   6
# 587                 3               5                   2
# 1170                2               4                   2
# 159                 3               4                   3
# ...               ...             ...                 ...
# 365                 4               1                   0
# 963                 3               7                   7
# 734                 2               4                   3
# 1315                3               1                   0
# 1292                3               2                   1
#
#       YearsSinceLastPromotion  YearsWithCurrManager
# 853                         0                     0
# 435                         7                     7
# 587                         1                     4
# 1170                        1                     2
# 159                         1                     2
# ...                       ...                   ...
# 365                         0                     0
# 963                         1                     7
# 734                         1                     1
# 1315                        0                     0
# 1292                        2                     2
#
# [1029 rows x 29 columns]

# %%
y_train
# Out:
# 853      No
# 435     Yes
# 587      No
# 1170     No
# 159      No
#        ...
# 365      No
# 963      No
# 734      No
# 1315     No
# 1292     No
# Name: Attrition, Length: 1029, dtype: object

# %%
train_data = X_train.copy()
train_data.reset_index(inplace=True, drop=True)
train_data['Attrition'] = ['no' if x == 'No' else 'yes' for x in y_train]
train_data
# Out:
#       Age     BusinessTravel  DailyRate              Department  \
# 0      19      Travel_Rarely        645  Research & Development
# 1      33      Travel_Rarely       1277  Research & Development
# 2      52      Travel_Rarely       1325  Research & Development
# 3      27  Travel_Frequently        591  Research & Development
# 4      34  Travel_Frequently        303                   Sales
# ...   ...                ...        ...                     ...
# 1024   46         Non-Travel       1144  Research & Development
# 1025   38      Travel_Rarely       1009                   Sales
# 1026   22      Travel_Rarely        217  Research & Development
# 1027   36      Travel_Rarely        430  Research & Development
# 1028   39  Travel_Frequently        766                   Sales
#
#       DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                    9          2  Life Sciences                        3
# 1                   15          1        Medical                        2
# 2                   11          4  Life Sciences                        4
# 3                    2          3        Medical                        4
# 4                    2          4      Marketing                        3
# ...                ...        ...            ...                      ...
# 1024                 7          4        Medical                        3
# 1025                 2          2  Life Sciences                        2
# 1026                 8          1  Life Sciences                        2
# 1027                 2          4          Other                        4
# 1028                20          3  Life Sciences                        3
#
#       Gender  HourlyRate  ...  RelationshipSatisfaction  StockOptionLevel  \
# 0       Male          54  ...                         3                 0
# 1       Male          56  ...                         4                 0
# 2     Female          82  ...                         2                 1
# 3       Male          87  ...                         3                 0
# 4     Female          75  ...                         4                 1
# ...      ...         ...  ...                       ...               ...
# 1024  Female          30  ...                         3                 0
# 1025  Female          31  ...                         4                 1
# 1026    Male          94  ...                         1                 1
# 1027  Female          73  ...                         4                 1
# 1028    Male          83  ...                         4                 1
#
#      TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                    1                      4               3               1
# 1                   15                      2               4               7
# 2                    9                      3               3               5
# 3                    6                      0               2               4
# 4                    6                      3               3               4
# ...                ...                    ...             ...             ...
# 1024                 7                      2               4               1
# 1025                11                      3               3               7
# 1026                 4                      3               2               4
# 1027                15                      2               3               1
# 1028                 7                      6               3               2
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                      1                        0                     0
# 1                      6                        7                     7
# 2                      2                        1                     4
# 3                      2                        1                     2
# 4                      3                        1                     2
# ...                  ...                      ...                   ...
# 1024                   0                        0                     0
# 1025                   7                        1                     7
# 1026                   3                        1                     1
# 1027                   0                        0                     0
# 1028                   1                        2                     2
#
#       Attrition
# 0            no
# 1           yes
# 2            no
# 3            no
# 4            no
# ...         ...
# 1024         no
# 1025         no
# 1026         no
# 1027         no
# 1028         no
#
# [1029 rows x 30 columns]

# %%
merged_train = pd.concat([train_data, train_probas], axis = 1)
merged_train.head()
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   19      Travel_Rarely        645  Research & Development
# 1   33      Travel_Rarely       1277  Research & Development
# 2   52      Travel_Rarely       1325  Research & Development
# 3   27  Travel_Frequently        591  Research & Development
# 4   34  Travel_Frequently        303                   Sales
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 9          2  Life Sciences                        3
# 1                15          1        Medical                        2
# 2                11          4  Life Sciences                        4
# 3                 2          3        Medical                        4
# 4                 2          4      Marketing                        3
#
#    Gender  HourlyRate  ...  TotalWorkingYears  TrainingTimesLastYear  \
# 0    Male          54  ...                  1                      4
# 1    Male          56  ...                 15                      2
# 2  Female          82  ...                  9                      3
# 3    Male          87  ...                  6                      0
# 4  Female          75  ...                  6                      3
#
#   WorkLifeBalance  YearsAtCompany YearsInCurrentRole  YearsSinceLastPromotion  \
# 0               3               1                  1                        0
# 1               4               7                  6                        7
# 2               3               5                  2                        1
# 3               2               4                  2                        1
# 4               3               4                  3                        1
#
#    YearsWithCurrManager  Attrition        no       yes
# 0                     0         no  0.657474  0.342526
# 1                     7        yes  0.868217  0.131783
# 2                     4         no  0.859321  0.140679
# 3                     2         no  0.834872  0.165128
# 4                     2         no  0.812314  0.187686
#
# [5 rows x 32 columns]

# %%
test_data = X_test.copy()
test_data.reset_index(inplace=True, drop=True)
test_data['Attrition'] = ['no' if x == 'No' else 'yes' for x in y_test]
test_data
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 0     25      Travel_Rarely        891                   Sales
# 1     37      Travel_Rarely        367  Research & Development
# 2     35      Travel_Rarely        538  Research & Development
# 3     31      Travel_Rarely        688                   Sales
# 4     34      Travel_Rarely       1480                   Sales
# ..   ...                ...        ...                     ...
# 436   38  Travel_Frequently       1490  Research & Development
# 437   40         Non-Travel       1142  Research & Development
# 438   33  Travel_Frequently       1076  Research & Development
# 439   29      Travel_Rarely       1092  Research & Development
# 440   45      Travel_Rarely       1385  Research & Development
#
#      DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                   4          2  Life Sciences                        2
# 1                  25          2        Medical                        3
# 2                  25          2          Other                        1
# 3                   7          3  Life Sciences                        3
# 4                   4          3  Life Sciences                        3
# ..                ...        ...            ...                      ...
# 436                 2          2  Life Sciences                        4
# 437                 8          2  Life Sciences                        4
# 438                 3          3  Life Sciences                        1
# 439                 1          4        Medical                        1
# 440                20          2        Medical                        3
#
#      Gender  HourlyRate  ...  RelationshipSatisfaction  StockOptionLevel  \
# 0    Female          99  ...                         2                 0
# 1    Female          52  ...                         3                 2
# 2      Male          54  ...                         4                 0
# 3      Male          44  ...                         3                 1
# 4      Male          64  ...                         4                 3
# ..      ...         ...  ...                       ...               ...
# 436    Male          42  ...                         3                 1
# 437    Male          72  ...                         3                 0
# 438    Male          70  ...                         1                 0
# 439    Male          36  ...                         2                 3
# 440    Male          79  ...                         2                 0
#
#     TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                   5                      3               3               5
# 1                   9                      2               3               6
# 2                   9                      3               3               3
# 3                  10                      3               2               5
# 4                   9                      3               3               5
# ..                ...                    ...             ...             ...
# 436                 1                      3               3               1
# 437                 8                      2               3               2
# 438                10                      3               3              10
# 439                 4                      3               4               2
# 440                21                      2               3              20
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                     4                        1                     3
# 1                     2                        1                     3
# 2                     2                        0                     2
# 3                     4                        0                     1
# 4                     3                        1                     0
# ..                  ...                      ...                   ...
# 436                   0                        0                     0
# 437                   2                        2                     2
# 438                   8                        9                     7
# 439                   2                        2                     2
# 440                   7                        4                    10
#
#      Attrition
# 0           no
# 1           no
# 2           no
# 3           no
# 4           no
# ..         ...
# 436         no
# 437         no
# 438        yes
# 439        yes
# 440         no
#
# [441 rows x 30 columns]

# %%
test_data.tail()
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 436   38  Travel_Frequently       1490  Research & Development
# 437   40         Non-Travel       1142  Research & Development
# 438   33  Travel_Frequently       1076  Research & Development
# 439   29      Travel_Rarely       1092  Research & Development
# 440   45      Travel_Rarely       1385  Research & Development
#
#      DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 436                 2          2  Life Sciences                        4
# 437                 8          2  Life Sciences                        4
# 438                 3          3  Life Sciences                        1
# 439                 1          4        Medical                        1
# 440                20          2        Medical                        3
#
#     Gender  HourlyRate  ...  RelationshipSatisfaction  StockOptionLevel  \
# 436   Male          42  ...                         3                 1
# 437   Male          72  ...                         3                 0
# 438   Male          70  ...                         1                 0
# 439   Male          36  ...                         2                 3
# 440   Male          79  ...                         2                 0
#
#     TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 436                 1                      3               3               1
# 437                 8                      2               3               2
# 438                10                      3               3              10
# 439                 4                      3               4               2
# 440                21                      2               3              20
#
#      YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 436                   0                        0                     0
# 437                   2                        2                     2
# 438                   8                        9                     7
# 439                   2                        2                     2
# 440                   7                        4                    10
#
#      Attrition
# 436         no
# 437         no
# 438        yes
# 439        yes
# 440         no
#
# [5 rows x 30 columns]

# %%
test_probas.tail()
# Out:
#            no       yes
# 436  0.832132  0.167868
# 437  0.851662  0.148338
# 438  0.916526  0.083474
# 439  0.764707  0.235293
# 440  0.964593  0.035407

# %%
merged_test = pd.concat([test_data, test_probas], axis = 1)
merged_test
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 0     25      Travel_Rarely        891                   Sales
# 1     37      Travel_Rarely        367  Research & Development
# 2     35      Travel_Rarely        538  Research & Development
# 3     31      Travel_Rarely        688                   Sales
# 4     34      Travel_Rarely       1480                   Sales
# ..   ...                ...        ...                     ...
# 436   38  Travel_Frequently       1490  Research & Development
# 437   40         Non-Travel       1142  Research & Development
# 438   33  Travel_Frequently       1076  Research & Development
# 439   29      Travel_Rarely       1092  Research & Development
# 440   45      Travel_Rarely       1385  Research & Development
#
#      DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                   4          2  Life Sciences                        2
# 1                  25          2        Medical                        3
# 2                  25          2          Other                        1
# 3                   7          3  Life Sciences                        3
# 4                   4          3  Life Sciences                        3
# ..                ...        ...            ...                      ...
# 436                 2          2  Life Sciences                        4
# 437                 8          2  Life Sciences                        4
# 438                 3          3  Life Sciences                        1
# 439                 1          4        Medical                        1
# 440                20          2        Medical                        3
#
#      Gender  HourlyRate  ...  TotalWorkingYears  TrainingTimesLastYear  \
# 0    Female          99  ...                  5                      3
# 1    Female          52  ...                  9                      2
# 2      Male          54  ...                  9                      3
# 3      Male          44  ...                 10                      3
# 4      Male          64  ...                  9                      3
# ..      ...         ...  ...                ...                    ...
# 436    Male          42  ...                  1                      3
# 437    Male          72  ...                  8                      2
# 438    Male          70  ...                 10                      3
# 439    Male          36  ...                  4                      3
# 440    Male          79  ...                 21                      2
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 0                 3               5                  4
# 1                 3               6                  2
# 2                 3               3                  2
# 3                 2               5                  4
# 4                 3               5                  3
# ..              ...             ...                ...
# 436               3               1                  0
# 437               3               2                  2
# 438               3              10                  8
# 439               4               2                  2
# 440               3              20                  7
#
#      YearsSinceLastPromotion  YearsWithCurrManager  Attrition        no  \
# 0                          1                     3         no  0.853423
# 1                          1                     3         no  0.648445
# 2                          0                     2         no  0.615813
# 3                          0                     1         no  0.808127
# 4                          1                     0         no  0.892689
# ..                       ...                   ...        ...       ...
# 436                        0                     0         no  0.832132
# 437                        2                     2         no  0.851662
# 438                        9                     7        yes  0.916526
# 439                        2                     2        yes  0.764707
# 440                        4                    10         no  0.964593
#
#           yes
# 0    0.146577
# 1    0.351555
# 2    0.384187
# 3    0.191873
# 4    0.107311
# ..        ...
# 436  0.167868
# 437  0.148338
# 438  0.083474
# 439  0.235293
# 440  0.035407
#
# [441 rows x 32 columns]

# %%
from evidently.dashboard import Dashboard
from evidently.dashboard.tabs import ClassificationPerformanceTab
from evidently.pipeline.column_mapping import ColumnMapping

# %%
numerical_features
# Out:
# ['Age',
#  'DailyRate',
#  'DistanceFromHome',
#  'Education',
#  'EnvironmentSatisfaction',
#  'HourlyRate',
#  'JobInvolvement',
#  'JobLevel',
#  'JobSatisfaction',
#  'MonthlyIncome',
#  'MonthlyRate',
#  'NumCompaniesWorked',
#  'PercentSalaryHike',
#  'PerformanceRating',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager']

# %%
categorical_features
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'JobRole',
#  'MaritalStatus']

# %%
column_mapping = ColumnMapping()

column_mapping.target = 'Attrition'
column_mapping.prediction = ['yes','no']

column_mapping.numerical_features = numerical_features

column_mapping.categorical_features = categorical_features

# %%
merged_test.sample(5)
# Out:
#      Age     BusinessTravel  DailyRate              Department  \
# 137   31  Travel_Frequently        715                   Sales
# 179   38  Travel_Frequently        471  Research & Development
# 431   32  Travel_Frequently        585  Research & Development
# 247   33      Travel_Rarely        832  Research & Development
# 99    37      Travel_Rarely       1192  Research & Development
#
#      DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 137                 2          4          Other                        4
# 179                12          3  Life Sciences                        1
# 431                10          3  Life Sciences                        1
# 247                 5          4  Life Sciences                        3
# 99                  5          2        Medical                        4
#
#      Gender  HourlyRate  ...  TotalWorkingYears  TrainingTimesLastYear  \
# 137    Male          54  ...                 10                      3
# 179    Male          45  ...                 13                      3
# 431    Male          56  ...                 10                      3
# 247  Female          63  ...                  2                      2
# 99     Male          61  ...                  8                      2
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 137               3               5                  2
# 179               2               4                  3
# 431               2               5                  2
# 247               2               2                  2
# 99                2               6                  2
#
#      YearsSinceLastPromotion  YearsWithCurrManager  Attrition        no  \
# 137                        0                     3         no  0.819461
# 179                        1                     2         no  0.822350
# 431                        1                     3         no  0.754041
# 247                        0                     2         no  0.807661
# 99                         0                     4         no  0.863389
#
#           yes
# 137  0.180539
# 179  0.177650
# 431  0.245959
# 247  0.192339
# 99   0.136611
#
# [5 rows x 32 columns]

# %%
from evidently.dashboard.tabs import ProbClassificationPerformanceTab
dashboard = Dashboard(tabs=[ProbClassificationPerformanceTab()])
dashboard.calculate(merged_train, merged_test, column_mapping = column_mapping)

# %%
dashboard.save('pipeline_ibm_hr_attrition_baseline_performance.html')

# %% [markdown]
# ## 2nd approach (Without using Column_Transformer and Pipeline)

# %%
df = pd.read_csv('./data/WA_Fn-UseC_-HR-Employee-Attrition.csv')
df.head()

# %%
df.drop(['Over18','EmployeeCount', 'EmployeeNumber', 'StandardHours'], axis="columns", inplace=True)
df["Attrition"] = df["Attrition"].apply(lambda x: 1 if x == "Yes" else 0)

# %%
df2 = df.copy(deep = True)

X = df2.drop("Attrition",axis=1)
y= df2["Attrition"]

categorical_features = list(X.select_dtypes(include="O").columns)
numerical_features = list(X.select_dtypes(include="number").columns)

target_name = 'Attrition'

X['Gender_Indicator'] = X.Gender.apply(
lambda x : 0 if x == 'Male' else 1 if x == 'Female' else -1)

business_travel_dummies = pd.get_dummies(X.BusinessTravel, prefix = 'b_travel')
X = pd.concat([X, business_travel_dummies], axis=1)

department_dummies = pd.get_dummies(X.Department, prefix = 'department')
X = pd.concat([X, department_dummies], axis=1)

edu_field_dummies = pd.get_dummies(X.Department, prefix = 'edu_field')
X = pd.concat([X, edu_field_dummies], axis=1)

job_role_dummies = pd.get_dummies(X.JobRole, prefix = 'job_role')
X = pd.concat([X, job_role_dummies], axis=1)

marital_dummies = pd.get_dummies(X.MaritalStatus, prefix = 'marital')
X = pd.concat([X, marital_dummies], axis=1) 

overtime_dummies = pd.get_dummies(X.OverTime, prefix = 'overtime')
X = pd.concat([X, overtime_dummies], axis=1)

X.drop(columns = categorical_features, inplace = True)



X_train, X_test, y_train, y_test = train_test_split(X, y,
                               random_state = 42, test_size = 0.30,
                               stratify = y)

# %%
X_train.head()

# %%
y_train.head()

# %%
rf = RandomForestClassifier(n_estimators=500, n_jobs = -1, random_state = 42)

# %%
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
accuracy_Score = accuracy_score(y_test, y_pred)
print(accuracy_Score)

# %%
y_pred = rf.predict_proba(X_test)[:,1]
ROC_AUC_Score = roc_auc_score(y_test, y_pred)
print(ROC_AUC_Score)

# %% [markdown]
# ### Performance Dashboad

# %%
train_probas = pd.DataFrame(rf.predict_proba(X_train))
train_probas.columns = ['no', 'yes']
train_probas

# %%
test_probas = pd.DataFrame(rf.predict_proba(X_test))
test_probas.columns = ['no', 'yes'] 
test_probas

# %%
X_train

# %%
X_train.reset_index(inplace=True, drop=True)
X_train

# %%
y_train

# %%
X_train['Attrition'] = ['no' if x == 0 else 'yes' for x in y_train]

# %%
train_merged = pd.concat([X_train, train_probas], axis = 1)
train_merged.head()

# %%
X_test.reset_index(inplace=True, drop=True)

# %%
X_test['Attrition'] = ['no' if x == 0 else 'yes' for x in y_test]

# %%
X_test.head()

# %%
test_merged = pd.concat([X_test, test_probas], axis = 1)
test_merged.head()

# %%
train_merged

# %%
column_mapping = ColumnMapping()

column_mapping.target = 'Attrition'
column_mapping.prediction = ['yes', 'no']

column_mapping.numerical_features = ['Age','DailyRate', 'DistanceFromHome', 'Education',
        'EnvironmentSatisfaction', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
       'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager']

column_mapping.categorical_features = ['b_travel_Non-Travel',
       'b_travel_Travel_Frequently', 'b_travel_Travel_Rarely',
       'department_Human Resources', 'department_Research & Development',
       'department_Sales', 'edu_field_Human Resources',
       'edu_field_Research & Development', 'edu_field_Sales', 'Gender_Indicator',
       'job_role_Healthcare Representative', 'job_role_Human Resources',
       'job_role_Laboratory Technician', 'job_role_Manager',
       'job_role_Manufacturing Director', 'job_role_Research Director',
       'job_role_Research Scientist', 'job_role_Sales Executive',
       'job_role_Sales Representative', 'marital_Divorced', 'marital_Married',
       'marital_Single', 'overtime_No', 'overtime_Yes']

# %%
from evidently.dashboard.tabs import ProbClassificationPerformanceTab

# %%
dashboard = Dashboard(tabs=[ProbClassificationPerformanceTab()])
dashboard.calculate(train_merged, test_merged, column_mapping = column_mapping)

dashboard.save('ibm_hr_attrition_baseline_performance.html')

# %%
# dashboard.show()
